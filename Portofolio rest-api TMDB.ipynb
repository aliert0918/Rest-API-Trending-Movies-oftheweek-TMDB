# %%
import os
from dotenv import load_dotenv
import nest_asyncio
import asyncio
import aiohttp
import pandas as pd
import warnings
from google.oauth2 import service_account
import pandas_gbq
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)
load_dotenv()
nest_asyncio.apply()
BASE_URL = "https://api.themoviedb.org/3"
ENDPOINT_TRENDING_MOVIE_WEEK = "/trending/movie/week"
TMDB_IMAGE_BASE = "https://image.tmdb.org/t/p/"
POSTER_SIZE = "w185"

# %%
load_dotenv("C:\\Users\\ALIF\\Documents\\Kelas JCDSBDGPM-10\\PORTO\\.env")
# Out:
# True

# %%
API_KEY = os.getenv("TMDB_API_KEY")

# %%
async def fetch_page(session: aiohttp.ClientSession, page: int) -> dict:
    url = BASE_URL + ENDPOINT_TRENDING_MOVIE_WEEK
    params = {"api_key": API_KEY, "page": page}

    async with session.get(url, params=params) as resp:
        status = resp.status
        data = await resp.json()

        print(f"Ambil page {page} ... status code: {status}")

        if status != 200:
            raise RuntimeError(f"Gagal ambil page {page}: status {status} | body: {data}")

        return data


async def fetch_trending_movie_week_async(
    max_pages: int | None = None,
    concurrency: int = 4
) -> pd.DataFrame:
    connector = aiohttp.TCPConnector(limit=None)
    async with aiohttp.ClientSession(connector=connector) as session:

        first_data = await fetch_page(session, page=1)
        total_pages_api = first_data["total_pages"]
        total_results = first_data["total_results"]

        if max_pages is None:
            n_pages = total_pages_api
        else:
            n_pages = min(max_pages, total_pages_api)

        print(f"\nTotal pages di API : {total_pages_api}")
        print(f"Total results di API : {total_results}")
        print(f"Pages yang di-fetch : 1..{n_pages}\n")

        all_results = list(first_data["results"])

        if n_pages == 1:
            df = pd.DataFrame(all_results)
            return df

        semaphore = asyncio.Semaphore(concurrency)

        async def bound_fetch(page: int) -> dict:
            async with semaphore:
                return await fetch_page(session, page)

        tasks = [
            asyncio.create_task(bound_fetch(page))
            for page in range(2, n_pages + 1)
        ]

        pages_data = await asyncio.gather(*tasks)

        for page_data in pages_data:
            all_results.extend(page_data["results"])

        df = pd.DataFrame(all_results)
        return df

# %%
# Jalankan coroutine dan dapatkan semua data
df_trending_all = await fetch_trending_movie_week_async(
    max_pages=None,      # ambil semua sampai total_pages (biasanya 500)
    concurrency=4        # boleh kamu ubah kalau mau
)

print("Shape sebelum dedup:", df_trending_all.shape)
display(df_trending_all.head())

before = len(df_trending_all)
df_trending_all = (
    df_trending_all
    .drop_duplicates(subset="id", keep="first")
    .reset_index(drop=True)
)
after = len(df_trending_all)

print(f"Baris sebelum : {before}")
print(f"Baris sesudah : {after}")
print(f"Duplikat dibuang: {before - after}")
print("Masih ada duplikat id?", df_trending_all["id"].duplicated().any())

kolom_penting = [
    "id",
    "title",
    "original_title",
    "overview",
    "release_date",
    "vote_average",
    "vote_count",
    "popularity",
    "media_type",
    "original_language",
    "poster_path",     
]

kolom_penting_ada = [k for k in kolom_penting if k in df_trending_all.columns]

df_trending_clean = df_trending_all[kolom_penting_ada].copy()

def make_poster_url(path):
    if not path or pd.isna(path):
        return None
    return f"{TMDB_IMAGE_BASE}{POSTER_SIZE}{path}"

df_trending_clean["poster_url"] = df_trending_clean["poster_path"].apply(make_poster_url)

df_trending_clean.head()
# Out:
# Ambil page 1 ... status code: 200
#
# Total pages di API : 500
# Total results di API : 10000
# Pages yang di-fetch : 1..500
#
# Ambil page 2 ... status code: 200
# Ambil page 6 ... status code: 200
# Ambil page 3 ... status code: 200
# Ambil page 4 ... status code: 200
# Ambil page 5 ... status code: 200
# Ambil page 7 ... status code: 200
# Ambil page 8 ... status code: 200
# Ambil page 9 ... status code: 200
# Ambil page 10 ... status code: 200
# Ambil page 11 ... status code: 200
# Ambil page 12 ... status code: 200
# Ambil page 13 ... status code: 200
# Ambil page 14 ... status code: 200
# Ambil page 15 ... status code: 200
# Ambil page 16 ... status code: 200
# Ambil page 17 ... status code: 200
# Ambil page 18 ... status code: 200
# Ambil page 19 ... status code: 200
# Ambil page 21 ... status code: 200
# Ambil page 22 ... status code: 200
# Ambil page 20 ... status code: 200
# Ambil page 23 ... status code: 200
# Ambil page 24 ... status code: 200
# Ambil page 25 ... status code: 200
# Ambil page 26 ... status code: 200
# Ambil page 27 ... status code: 200
# Ambil page 28 ... status code: 200
# Ambil page 29 ... status code: 200
# Ambil page 30 ... status code: 200
# Ambil page 31 ... status code: 200
# Ambil page 32 ... status code: 200
# Ambil page 34 ... status code: 200
# Ambil page 33 ... status code: 200
# Ambil page 35 ... status code: 200
# Ambil page 37 ... status code: 200
# Ambil page 36 ... status code: 200
# Ambil page 38 ... status code: 200
# Ambil page 39 ... status code: 200
# Ambil page 40 ... status code: 200
# Ambil page 41 ... status code: 200
# Ambil page 42 ... status code: 200
# Ambil page 43 ... status code: 200
# Ambil page 44 ... status code: 200
# Ambil page 45 ... status code: 200
# Ambil page 47 ... status code: 200
# Ambil page 46 ... status code: 200
# Ambil page 48 ... status code: 200
# Ambil page 49 ... status code: 200
# Ambil page 50 ... status code: 200
# Ambil page 51 ... status code: 200
# Ambil page 52 ... status code: 200
# Ambil page 53 ... status code: 200
# Ambil page 54 ... status code: 200
# Ambil page 55 ... status code: 200
# Ambil page 56 ... status code: 200
# Ambil page 57 ... status code: 200
# Ambil page 58 ... status code: 200
# Ambil page 59 ... status code: 200
# Ambil page 60 ... status code: 200
# Ambil page 61 ... status code: 200
# Ambil page 63 ... status code: 200
# Ambil page 62 ... status code: 200
# Ambil page 64 ... status code: 200
# Ambil page 65 ... status code: 200
# Ambil page 66 ... status code: 200
# Ambil page 67 ... status code: 200
# Ambil page 68 ... status code: 200
# Ambil page 69 ... status code: 200
# Ambil page 70 ... status code: 200
# Ambil page 71 ... status code: 200
# Ambil page 73 ... status code: 200
# Ambil page 72 ... status code: 200
# Ambil page 75 ... status code: 200
# Ambil page 74 ... status code: 200
# Ambil page 77 ... status code: 200
# Ambil page 76 ... status code: 200
# Ambil page 78 ... status code: 200
# Ambil page 79 ... status code: 200
# Ambil page 80 ... status code: 200
# Ambil page 81 ... status code: 200
# Ambil page 83 ... status code: 200
# Ambil page 82 ... status code: 200
# Ambil page 84 ... status code: 200
# Ambil page 85 ... status code: 200
# Ambil page 86 ... status code: 200
# Ambil page 87 ... status code: 200
# Ambil page 88 ... status code: 200
# Ambil page 89 ... status code: 200
# Ambil page 91 ... status code: 200
# Ambil page 90 ... status code: 200
# Ambil page 92 ... status code: 200
# Ambil page 93 ... status code: 200
# Ambil page 94 ... status code: 200
# Ambil page 95 ... status code: 200
# Ambil page 96 ... status code: 200
# Ambil page 97 ... status code: 200
# Ambil page 99 ... status code: 200
# Ambil page 98 ... status code: 200
# Ambil page 101 ... status code: 200
# Ambil page 100 ... status code: 200
# Ambil page 102 ... status code: 200
# Ambil page 103 ... status code: 200
# Ambil page 105 ... status code: 200
# Ambil page 104 ... status code: 200
# Ambil page 106 ... status code: 200
# Ambil page 107 ... status code: 200
# Ambil page 108 ... status code: 200
# Ambil page 109 ... status code: 200
# Ambil page 111 ... status code: 200
# Ambil page 110 ... status code: 200
# Ambil page 113 ... status code: 200
# Ambil page 112 ... status code: 200
# Ambil page 114 ... status code: 200
# Ambil page 115 ... status code: 200
# Ambil page 116 ... status code: 200
# Ambil page 117 ... status code: 200
# Ambil page 118 ... status code: 200
# Ambil page 119 ... status code: 200
# Ambil page 120 ... status code: 200
# Ambil page 121 ... status code: 200
# Ambil page 122 ... status code: 200
# Ambil page 123 ... status code: 200
# Ambil page 124 ... status code: 200
# Ambil page 125 ... status code: 200
# Ambil page 126 ... status code: 200
# Ambil page 127 ... status code: 200
# Ambil page 128 ... status code: 200
# Ambil page 129 ... status code: 200
# Ambil page 130 ... status code: 200
# Ambil page 131 ... status code: 200
# Ambil page 132 ... status code: 200
# Ambil page 133 ... status code: 200
# Ambil page 134 ... status code: 200
# Ambil page 135 ... status code: 200
# Ambil page 136 ... status code: 200
# Ambil page 137 ... status code: 200
# Ambil page 138 ... status code: 200
# Ambil page 139 ... status code: 200
# Ambil page 140 ... status code: 200
# Ambil page 141 ... status code: 200
# Ambil page 142 ... status code: 200
# Ambil page 143 ... status code: 200
# Ambil page 144 ... status code: 200
# Ambil page 145 ... status code: 200
# Ambil page 146 ... status code: 200
# Ambil page 147 ... status code: 200
# Ambil page 148 ... status code: 200
# Ambil page 149 ... status code: 200
# Ambil page 150 ... status code: 200
# Ambil page 151 ... status code: 200
# Ambil page 152 ... status code: 200
# Ambil page 153 ... status code: 200
# Ambil page 154 ... status code: 200
# Ambil page 155 ... status code: 200
# Ambil page 156 ... status code: 200
# Ambil page 157 ... status code: 200
# Ambil page 158 ... status code: 200
# Ambil page 159 ... status code: 200
# Ambil page 160 ... status code: 200
# Ambil page 161 ... status code: 200
# Ambil page 162 ... status code: 200
# Ambil page 163 ... status code: 200
# Ambil page 164 ... status code: 200
# Ambil page 165 ... status code: 200
# Ambil page 166 ... status code: 200
# Ambil page 167 ... status code: 200
# Ambil page 168 ... status code: 200
# Ambil page 169 ... status code: 200
# Ambil page 170 ... status code: 200
# Ambil page 171 ... status code: 200
# Ambil page 172 ... status code: 200
# Ambil page 173 ... status code: 200
# Ambil page 174 ... status code: 200
# Ambil page 175 ... status code: 200
# Ambil page 176 ... status code: 200
# Ambil page 177 ... status code: 200
# Ambil page 178 ... status code: 200
# Ambil page 179 ... status code: 200
# Ambil page 180 ... status code: 200
# Ambil page 181 ... status code: 200
# Ambil page 183 ... status code: 200
# Ambil page 184 ... status code: 200
# Ambil page 182 ... status code: 200
# Ambil page 185 ... status code: 200
# Ambil page 186 ... status code: 200
# Ambil page 187 ... status code: 200
# Ambil page 188 ... status code: 200
# Ambil page 189 ... status code: 200
# Ambil page 190 ... status code: 200
# Ambil page 192 ... status code: 200
# Ambil page 191 ... status code: 200
# Ambil page 193 ... status code: 200
# Ambil page 195 ... status code: 200
# Ambil page 196 ... status code: 200
# Ambil page 194 ... status code: 200
# Ambil page 197 ... status code: 200
# Ambil page 199 ... status code: 200
# Ambil page 200 ... status code: 200
# Ambil page 201 ... status code: 200
# Ambil page 198 ... status code: 200
# Ambil page 202 ... status code: 200
# Ambil page 203 ... status code: 200
# Ambil page 204 ... status code: 200
# Ambil page 205 ... status code: 200
# Ambil page 206 ... status code: 200
# Ambil page 207 ... status code: 200
# Ambil page 208 ... status code: 200
# Ambil page 209 ... status code: 200
# Ambil page 211 ... status code: 200
# Ambil page 210 ... status code: 200
# Ambil page 212 ... status code: 200
# Ambil page 213 ... status code: 200
# Ambil page 214 ... status code: 200
# Ambil page 215 ... status code: 200
# Ambil page 216 ... status code: 200
# Ambil page 217 ... status code: 200
# Ambil page 218 ... status code: 200
# Ambil page 219 ... status code: 200
# Ambil page 221 ... status code: 200
# Ambil page 220 ... status code: 200
# Ambil page 222 ... status code: 200
# Ambil page 223 ... status code: 200
# Ambil page 224 ... status code: 200
# Ambil page 225 ... status code: 200
# Ambil page 226 ... status code: 200
# Ambil page 227 ... status code: 200
# Ambil page 228 ... status code: 200
# Ambil page 229 ... status code: 200
# Ambil page 230 ... status code: 200
# Ambil page 231 ... status code: 200
# Ambil page 232 ... status code: 200
# Ambil page 233 ... status code: 200
# Ambil page 234 ... status code: 200
# Ambil page 235 ... status code: 200
# Ambil page 236 ... status code: 200
# Ambil page 237 ... status code: 200
# Ambil page 238 ... status code: 200
# Ambil page 240 ... status code: 200
# Ambil page 239 ... status code: 200
# Ambil page 241 ... status code: 200
# Ambil page 242 ... status code: 200
# Ambil page 243 ... status code: 200
# Ambil page 244 ... status code: 200
# Ambil page 245 ... status code: 200
# Ambil page 246 ... status code: 200
# Ambil page 247 ... status code: 200
# Ambil page 248 ... status code: 200
# Ambil page 249 ... status code: 200
# Ambil page 250 ... status code: 200
# Ambil page 251 ... status code: 200
# Ambil page 252 ... status code: 200
# Ambil page 253 ... status code: 200
# Ambil page 255 ... status code: 200
# Ambil page 254 ... status code: 200
# Ambil page 256 ... status code: 200
# Ambil page 257 ... status code: 200
# Ambil page 259 ... status code: 200
# Ambil page 258 ... status code: 200
# Ambil page 260 ... status code: 200
# Ambil page 261 ... status code: 200
# Ambil page 262 ... status code: 200
# Ambil page 263 ... status code: 200
# Ambil page 264 ... status code: 200
# Ambil page 265 ... status code: 200
# Ambil page 267 ... status code: 200
# Ambil page 266 ... status code: 200
# Ambil page 269 ... status code: 200
# Ambil page 268 ... status code: 200
# Ambil page 271 ... status code: 200
# Ambil page 270 ... status code: 200
# Ambil page 272 ... status code: 200
# Ambil page 273 ... status code: 200
# Ambil page 274 ... status code: 200
# Ambil page 275 ... status code: 200
# Ambil page 276 ... status code: 200
# Ambil page 277 ... status code: 200
# Ambil page 279 ... status code: 200
# Ambil page 278 ... status code: 200
# Ambil page 280 ... status code: 200
# Ambil page 281 ... status code: 200
# Ambil page 282 ... status code: 200
# Ambil page 283 ... status code: 200
# Ambil page 284 ... status code: 200
# Ambil page 285 ... status code: 200
# Ambil page 286 ... status code: 200
# Ambil page 287 ... status code: 200
# Ambil page 288 ... status code: 200
# Ambil page 289 ... status code: 200
# Ambil page 290 ... status code: 200
# Ambil page 291 ... status code: 200
# Ambil page 292 ... status code: 200
# Ambil page 293 ... status code: 200
# Ambil page 294 ... status code: 200
# Ambil page 296 ... status code: 200
# Ambil page 295 ... status code: 200
# Ambil page 297 ... status code: 200
# Ambil page 298 ... status code: 200
# Ambil page 299 ... status code: 200
# Ambil page 300 ... status code: 200
# Ambil page 301 ... status code: 200
# Ambil page 302 ... status code: 200
# Ambil page 304 ... status code: 200
# Ambil page 303 ... status code: 200
# Ambil page 305 ... status code: 200
# Ambil page 306 ... status code: 200
# Ambil page 307 ... status code: 200
# Ambil page 309 ... status code: 200
# Ambil page 308 ... status code: 200
# Ambil page 310 ... status code: 200
# Ambil page 311 ... status code: 200
# Ambil page 313 ... status code: 200
# Ambil page 312 ... status code: 200
# Ambil page 314 ... status code: 200
# Ambil page 315 ... status code: 200
# Ambil page 317 ... status code: 200
# Ambil page 316 ... status code: 200
# Ambil page 318 ... status code: 200
# Ambil page 319 ... status code: 200
# Ambil page 320 ... status code: 200
# Ambil page 321 ... status code: 200
# Ambil page 322 ... status code: 200
# Ambil page 323 ... status code: 200
# Ambil page 325 ... status code: 200
# Ambil page 324 ... status code: 200
# Ambil page 326 ... status code: 200
# Ambil page 327 ... status code: 200
# Ambil page 329 ... status code: 200
# Ambil page 328 ... status code: 200
# Ambil page 330 ... status code: 200
# Ambil page 331 ... status code: 200
# Ambil page 332 ... status code: 200
# Ambil page 333 ... status code: 200
# Ambil page 334 ... status code: 200
# Ambil page 335 ... status code: 200
# Ambil page 336 ... status code: 200
# Ambil page 337 ... status code: 200
# Ambil page 338 ... status code: 200
# Ambil page 339 ... status code: 200
# Ambil page 340 ... status code: 200
# Ambil page 341 ... status code: 200
# Ambil page 342 ... status code: 200
# Ambil page 343 ... status code: 200
# Ambil page 344 ... status code: 200
# Ambil page 345 ... status code: 200
# Ambil page 346 ... status code: 200
# Ambil page 347 ... status code: 200
# Ambil page 348 ... status code: 200
# Ambil page 349 ... status code: 200
# Ambil page 350 ... status code: 200
# Ambil page 351 ... status code: 200
# Ambil page 353 ... status code: 200
# Ambil page 352 ... status code: 200
# Ambil page 354 ... status code: 200
# Ambil page 355 ... status code: 200
# Ambil page 356 ... status code: 200
# Ambil page 357 ... status code: 200
# Ambil page 358 ... status code: 200
# Ambil page 359 ... status code: 200
# Ambil page 360 ... status code: 200
# Ambil page 361 ... status code: 200
# Ambil page 362 ... status code: 200
# Ambil page 363 ... status code: 200
# Ambil page 365 ... status code: 200
# Ambil page 364 ... status code: 200
# Ambil page 367 ... status code: 200
# Ambil page 366 ... status code: 200
# Ambil page 368 ... status code: 200
# Ambil page 369 ... status code: 200
# Ambil page 370 ... status code: 200
# Ambil page 371 ... status code: 200
# Ambil page 372 ... status code: 200
# Ambil page 373 ... status code: 200
# Ambil page 374 ... status code: 200
# Ambil page 375 ... status code: 200
# Ambil page 376 ... status code: 200
# Ambil page 377 ... status code: 200
# Ambil page 378 ... status code: 200
# Ambil page 379 ... status code: 200
# Ambil page 381 ... status code: 200
# Ambil page 380 ... status code: 200
# Ambil page 382 ... status code: 200
# Ambil page 383 ... status code: 200
# Ambil page 385 ... status code: 200
# Ambil page 384 ... status code: 200
# Ambil page 386 ... status code: 200
# Ambil page 387 ... status code: 200
# Ambil page 388 ... status code: 200
# Ambil page 389 ... status code: 200
# Ambil page 390 ... status code: 200
# Ambil page 391 ... status code: 200
# Ambil page 392 ... status code: 200
# Ambil page 393 ... status code: 200
# Ambil page 394 ... status code: 200
# Ambil page 395 ... status code: 200
# Ambil page 396 ... status code: 200
# Ambil page 397 ... status code: 200
# Ambil page 398 ... status code: 200
# Ambil page 399 ... status code: 200
# Ambil page 400 ... status code: 200
# Ambil page 401 ... status code: 200
# Ambil page 402 ... status code: 200
# Ambil page 403 ... status code: 200
# Ambil page 404 ... status code: 200
# Ambil page 405 ... status code: 200
# Ambil page 406 ... status code: 200
# Ambil page 407 ... status code: 200
# Ambil page 408 ... status code: 200
# Ambil page 409 ... status code: 200
# Ambil page 410 ... status code: 200
# Ambil page 411 ... status code: 200
# Ambil page 412 ... status code: 200
# Ambil page 413 ... status code: 200
# Ambil page 414 ... status code: 200
# Ambil page 415 ... status code: 200
# Ambil page 416 ... status code: 200
# Ambil page 417 ... status code: 200
# Ambil page 418 ... status code: 200
# Ambil page 419 ... status code: 200
# Ambil page 420 ... status code: 200
# Ambil page 421 ... status code: 200
# Ambil page 422 ... status code: 200
# Ambil page 423 ... status code: 200
# Ambil page 424 ... status code: 200
# Ambil page 425 ... status code: 200
# Ambil page 426 ... status code: 200
# Ambil page 427 ... status code: 200
# Ambil page 428 ... status code: 200
# Ambil page 429 ... status code: 200
# Ambil page 430 ... status code: 200
# Ambil page 431 ... status code: 200
# Ambil page 432 ... status code: 200
# Ambil page 433 ... status code: 200
# Ambil page 434 ... status code: 200
# Ambil page 435 ... status code: 200
# Ambil page 436 ... status code: 200
# Ambil page 437 ... status code: 200
# Ambil page 438 ... status code: 200
# Ambil page 439 ... status code: 200
# Ambil page 441 ... status code: 200
# Ambil page 440 ... status code: 200
# Ambil page 442 ... status code: 200
# Ambil page 443 ... status code: 200
# Ambil page 444 ... status code: 200
# Ambil page 445 ... status code: 200
# Ambil page 446 ... status code: 200
# Ambil page 447 ... status code: 200
# Ambil page 448 ... status code: 200
# Ambil page 449 ... status code: 200
# Ambil page 450 ... status code: 200
# Ambil page 451 ... status code: 200
# Ambil page 452 ... status code: 200
# Ambil page 453 ... status code: 200
# Ambil page 454 ... status code: 200
# Ambil page 455 ... status code: 200
# Ambil page 456 ... status code: 200
# Ambil page 457 ... status code: 200
# Ambil page 459 ... status code: 200
# Ambil page 458 ... status code: 200
# Ambil page 460 ... status code: 200
# Ambil page 461 ... status code: 200
# Ambil page 462 ... status code: 200
# Ambil page 463 ... status code: 200
# Ambil page 464 ... status code: 200
# Ambil page 465 ... status code: 200
# Ambil page 466 ... status code: 200
# Ambil page 467 ... status code: 200
# Ambil page 468 ... status code: 200
# Ambil page 469 ... status code: 200
# Ambil page 471 ... status code: 200
# Ambil page 470 ... status code: 200
# Ambil page 472 ... status code: 200
# Ambil page 473 ... status code: 200
# Ambil page 475 ... status code: 200
# Ambil page 474 ... status code: 200
# Ambil page 476 ... status code: 200
# Ambil page 477 ... status code: 200
# Ambil page 478 ... status code: 200
# Ambil page 479 ... status code: 200
# Ambil page 480 ... status code: 200
# Ambil page 481 ... status code: 200
# Ambil page 482 ... status code: 200
# Ambil page 483 ... status code: 200
# Ambil page 484 ... status code: 200
# Ambil page 486 ... status code: 200
# Ambil page 487 ... status code: 200
# Ambil page 485 ... status code: 200
# Ambil page 488 ... status code: 200
# Ambil page 489 ... status code: 200
# Ambil page 490 ... status code: 200
# Ambil page 491 ... status code: 200
# Ambil page 492 ... status code: 200
# Ambil page 493 ... status code: 200
# Ambil page 494 ... status code: 200
# Ambil page 496 ... status code: 200
# Ambil page 495 ... status code: 200
# Ambil page 497 ... status code: 200
# Ambil page 498 ... status code: 200
# Ambil page 499 ... status code: 200
# Ambil page 500 ... status code: 200
# Shape sebelum dedup: (9985, 15)
#    adult                     backdrop_path       id              title  \
# 0  False  /5h2EsPKNDdB3MAtOk9MB9Ycg9Rz.jpg  1084242         Zootopia 2
# 1  False  /uPvsuTYc2fgEYgp3Ib2INoGep0n.jpg   701387            Bugonia
# 2  False  /l8pwO23MCvqYumzozpxynCNfck1.jpg   967941   Wicked: For Good
# 3  False  /7nAVXGHHtaNcdsqvDXmY6R9N0fG.jpg  1363123  The Family Plan 2
# 4  False  /u5NWHVhZ6HWc1fXnqn82cMar5St.jpg  1241983       Train Dreams
#
#       original_title                                           overview  \
# 0         Zootopia 2  After cracking the biggest case in Zootopia's ...
# 1            Bugonia  Two conspiracy obsessed young men kidnap the h...
# 2   Wicked: For Good  As an angry mob rises against the Wicked Witch...
# 3  The Family Plan 2  Now that Dan's assassin days are behind him, a...
# 4       Train Dreams  A logger leads a life of quiet grace as he exp...
#
#                         poster_path media_type original_language  \
# 0  /oJ7g2CifqpStmoYQyaLQgEU32qO.jpg      movie                en
# 1  /oxgsAQDAAxA92mFGYCZllgWkH9J.jpg      movie                en
# 2  /si9tolnefLSUKaqQEGz1bWArOaL.jpg      movie                en
# 3  /semFxuYx6HcrkZzslgAkBqfJvZk.jpg      movie                en
# 4  /l3zS4YnpOi4usyEXGJMtxSqDDyb.jpg      movie                en
#
#                    genre_ids  popularity release_date  video  vote_average  \
# 0  [16, 10751, 35, 12, 9648]    372.4120   2025-11-26  False         7.559
# 1              [35, 80, 878]    109.3434   2025-10-23  False         7.610
# 2            [14, 12, 10749]    230.2695   2025-11-19  False         6.790
# 3                   [28, 35]    374.8090   2025-11-11  False         6.821
# 4                       [18]     97.5006   2025-11-05  False         7.388
#
#    vote_count
# 0          76
# 1         451
# 2         274
# 3         196
# 4         139
# Baris sebelum : 9985
# Baris sesudah : 9785
# Duplikat dibuang: 200
# Masih ada duplikat id? False
#         id              title     original_title  \
# 0  1084242         Zootopia 2         Zootopia 2
# 1   701387            Bugonia            Bugonia
# 2   967941   Wicked: For Good   Wicked: For Good
# 3  1363123  The Family Plan 2  The Family Plan 2
# 4  1241983       Train Dreams       Train Dreams
#
#                                             overview release_date  \
# 0  After cracking the biggest case in Zootopia's ...   2025-11-26
# 1  Two conspiracy obsessed young men kidnap the h...   2025-10-23
# 2  As an angry mob rises against the Wicked Witch...   2025-11-19
# 3  Now that Dan's assassin days are behind him, a...   2025-11-11
# 4  A logger leads a life of quiet grace as he exp...   2025-11-05
#
#    vote_average  vote_count  popularity media_type original_language  \
# 0         7.559          76    372.4120      movie                en
# 1         7.610         451    109.3434      movie                en
# 2         6.790         274    230.2695      movie                en
# 3         6.821         196    374.8090      movie                en
# 4         7.388         139     97.5006      movie                en
#
#                         poster_path  \
# 0  /oJ7g2CifqpStmoYQyaLQgEU32qO.jpg
# 1  /oxgsAQDAAxA92mFGYCZllgWkH9J.jpg
# 2  /si9tolnefLSUKaqQEGz1bWArOaL.jpg
# 3  /semFxuYx6HcrkZzslgAkBqfJvZk.jpg
# 4  /l3zS4YnpOi4usyEXGJMtxSqDDyb.jpg
#
#                                           poster_url
# 0  https://image.tmdb.org/t/p/w185/oJ7g2CifqpStmo...
# 1  https://image.tmdb.org/t/p/w185/oxgsAQDAAxA92m...
# 2  https://image.tmdb.org/t/p/w185/si9tolnefLSUKa...
# 3  https://image.tmdb.org/t/p/w185/semFxuYx6HcrkZ...
# 4  https://image.tmdb.org/t/p/w185/l3zS4YnpOi4usy...

# %%
async def get_genre_mapping_async(language: str = "en-US") -> dict:
    """
    Ambil daftar genre movie dari TMDB.
    
    Return:
        dict {genre_id: genre_name}
    """
    url = BASE_URL + "/genre/movie/list"
    params = {"api_key": API_KEY, "language": language}

    async with aiohttp.ClientSession() as session:
        async with session.get(url, params=params) as resp:
            status = resp.status
            data = await resp.json()
            print(f"Ambil genre list ... status code: {status}")

            if status != 200:
                raise RuntimeError(
                    f"Gagal ambil genre list: status {status} | body: {data}"
                )

    genres = data.get("genres", [])
    return {g["id"]: g["name"] for g in genres}

genre_map = await get_genre_mapping_async(language="en-US")

genre_map
# Out:
# Ambil genre list ... status code: 200
# {28: 'Action',
#  12: 'Adventure',
#  16: 'Animation',
#  35: 'Comedy',
#  80: 'Crime',
#  99: 'Documentary',
#  18: 'Drama',
#  10751: 'Family',
#  14: 'Fantasy',
#  36: 'History',
#  27: 'Horror',
#  10402: 'Music',
#  9648: 'Mystery',
#  10749: 'Romance',
#  878: 'Science Fiction',
#  10770: 'TV Movie',
#  53: 'Thriller',
#  10752: 'War',
#  37: 'Western'}

# %%
# --- Buat kolom 'genres' (nama genre berdasarkan 'genre_ids') ---

def map_genre_ids_to_names(genre_ids):
    """
    genre_ids: list of int, misalnya [28, 12]
    return: string, misalnya "Action, Adventure"
    """
    if not isinstance(genre_ids, (list, tuple)):
        return None
    names = [genre_map.get(gid) for gid in genre_ids if gid in genre_map]
    if not names:
        return None
    return ", ".join(names)

df_trending_all["genres"] = df_trending_all["genre_ids"].apply(map_genre_ids_to_names)

df_trending_all[["title", "genre_ids", "genres"]].head()
# Out:
#                title                  genre_ids  \
# 0         Zootopia 2  [16, 10751, 35, 12, 9648]
# 1            Bugonia              [35, 80, 878]
# 2   Wicked: For Good            [14, 12, 10749]
# 3  The Family Plan 2                   [28, 35]
# 4       Train Dreams                       [18]
#
#                                           genres
# 0  Animation, Family, Comedy, Adventure, Mystery
# 1                 Comedy, Crime, Science Fiction
# 2                    Fantasy, Adventure, Romance
# 3                                 Action, Comedy
# 4                                          Drama

# %%
# Movie Indonesia
df_movie_indo = df_trending_clean[
    df_trending_clean["original_language"] == "id"
].copy()
df_movie_indo["segment"] = "indonesia"

# Movie Global
df_movie_global = df_trending_clean[
    df_trending_clean["original_language"] != "id"
].copy()
df_movie_global["segment"] = "global"

# %%
kolom_penting = [
    "id",
    "title",              # nama movie
    "overview",
    "release_date",
    "vote_average",
    "vote_count",
    "popularity",
    "media_type",         # di trending movie/week isinya "movie"
    "original_language",
    "poster_path",
    "genre_ids",
    "genres",             # kolom nama genre hasil mapping
]

kolom_penting_ada = [k for k in kolom_penting if k in df_trending_all.columns]
df_trending_clean = df_trending_all[kolom_penting_ada].copy()

df_trending_clean.head()
# Out:
#         id              title  \
# 0  1084242         Zootopia 2
# 1   701387            Bugonia
# 2   967941   Wicked: For Good
# 3  1363123  The Family Plan 2
# 4  1241983       Train Dreams
#
#                                             overview release_date  \
# 0  After cracking the biggest case in Zootopia's ...   2025-11-26
# 1  Two conspiracy obsessed young men kidnap the h...   2025-10-23
# 2  As an angry mob rises against the Wicked Witch...   2025-11-19
# 3  Now that Dan's assassin days are behind him, a...   2025-11-11
# 4  A logger leads a life of quiet grace as he exp...   2025-11-05
#
#    vote_average  vote_count  popularity media_type original_language  \
# 0         7.559          76    372.4120      movie                en
# 1         7.610         451    109.3434      movie                en
# 2         6.790         274    230.2695      movie                en
# 3         6.821         196    374.8090      movie                en
# 4         7.388         139     97.5006      movie                en
#
#                         poster_path                  genre_ids  \
# 0  /oJ7g2CifqpStmoYQyaLQgEU32qO.jpg  [16, 10751, 35, 12, 9648]
# 1  /oxgsAQDAAxA92mFGYCZllgWkH9J.jpg              [35, 80, 878]
# 2  /si9tolnefLSUKaqQEGz1bWArOaL.jpg            [14, 12, 10749]
# 3  /semFxuYx6HcrkZzslgAkBqfJvZk.jpg                   [28, 35]
# 4  /l3zS4YnpOi4usyEXGJMtxSqDDyb.jpg                       [18]
#
#                                           genres
# 0  Animation, Family, Comedy, Adventure, Mystery
# 1                 Comedy, Crime, Science Fiction
# 2                    Fantasy, Adventure, Romance
# 3                                 Action, Comedy
# 4                                          Drama

# %%
# Movie Indonesia
df_movie_id = df_trending_clean[
    df_trending_clean["original_language"] == "id"
].copy()
df_movie_id["segment"] = "indonesia"

# Movie Global (selain Indonesia)
df_movie_global = df_trending_clean[
    df_trending_clean["original_language"] != "id"
].copy()
df_movie_global["segment"] = "global"

print("Jumlah movie Indonesia :", len(df_movie_id))
print("Jumlah movie global    :", len(df_movie_global))

display(df_movie_id.head())
display(df_movie_global.head())
# Out:
# Jumlah movie Indonesia : 53
# Jumlah movie global    : 9732
#            id                          title  \
# 561   1391153  The Book of Sijjin & Illiyyin
# 715   1306525                     The Elixir
# 753   1287571    Agak Laen: Menyala Pantiku!
# 1026  1393334                      Smothered
# 1122  1385536   Sore: A Wife From The Future
#
#                                                overview release_date  \
# 561   As a child, Yuli witnessed her parents die at ...   2025-07-17
# 715   An elixir unleashes the undead in a village. A...   2025-10-22
# 753   After repeatedly failing their missions, Detec...   2025-11-27
# 1026  After surviving an accident, Alif, a micro-pai...   2025-11-27
# 1122  A young man living alone in Croatia encounters...   2025-07-10
#
#       vote_average  vote_count  popularity media_type original_language  \
# 561            7.4           4     12.3790      movie                id
# 715            6.0         141     14.0832      movie                id
# 753            8.5           2     17.5012      movie                id
# 1026           7.0           1      2.5688      movie                id
# 1122           8.9          15      5.2051      movie                id
#
#                            poster_path             genre_ids  \
# 561   /5c8iXGH5Vol8HfpdwXK5ptHKQ6R.jpg              [27, 53]
# 715   /A6aJLPhtmin9ZTWC2h7dnrMHU4z.jpg              [27, 53]
# 753   /48Lbiwc8QiaGXhpfHkWExLgIcaa.jpg    [35, 80, 18, 9648]
# 1026  /5qX69jou3zFKjdyp4b4tAK0jGfD.jpg        [18, 9648, 53]
# 1122  /u4pNXPmBuYeTtksakUCZgJ1zpSB.jpg  [14, 10749, 18, 878]
#
#                                         genres    segment
# 561                           Horror, Thriller  indonesia
# 715                           Horror, Thriller  indonesia
# 753              Comedy, Crime, Drama, Mystery  indonesia
# 1026                  Drama, Mystery, Thriller  indonesia
# 1122  Fantasy, Romance, Drama, Science Fiction  indonesia
#         id              title  \
# 0  1084242         Zootopia 2
# 1   701387            Bugonia
# 2   967941   Wicked: For Good
# 3  1363123  The Family Plan 2
# 4  1241983       Train Dreams
#
#                                             overview release_date  \
# 0  After cracking the biggest case in Zootopia's ...   2025-11-26
# 1  Two conspiracy obsessed young men kidnap the h...   2025-10-23
# 2  As an angry mob rises against the Wicked Witch...   2025-11-19
# 3  Now that Dan's assassin days are behind him, a...   2025-11-11
# 4  A logger leads a life of quiet grace as he exp...   2025-11-05
#
#    vote_average  vote_count  popularity media_type original_language  \
# 0         7.559          76    372.4120      movie                en
# 1         7.610         451    109.3434      movie                en
# 2         6.790         274    230.2695      movie                en
# 3         6.821         196    374.8090      movie                en
# 4         7.388         139     97.5006      movie                en
#
#                         poster_path                  genre_ids  \
# 0  /oJ7g2CifqpStmoYQyaLQgEU32qO.jpg  [16, 10751, 35, 12, 9648]
# 1  /oxgsAQDAAxA92mFGYCZllgWkH9J.jpg              [35, 80, 878]
# 2  /si9tolnefLSUKaqQEGz1bWArOaL.jpg            [14, 12, 10749]
# 3  /semFxuYx6HcrkZzslgAkBqfJvZk.jpg                   [28, 35]
# 4  /l3zS4YnpOi4usyEXGJMtxSqDDyb.jpg                       [18]
#
#                                           genres segment
# 0  Animation, Family, Comedy, Adventure, Mystery  global
# 1                 Comedy, Crime, Science Fiction  global
# 2                    Fantasy, Adventure, Romance  global
# 3                                 Action, Comedy  global
# 4                                          Drama  global

# %%
project_id = "the-movies-weekly"
dataset_id = "movie_analytics"

# path file service account, sesuaikan dengan punyamu
pathjsonnn = "C:\\Users\\ALIF\\Documents\\Kelas JCDSBDGPM-10\\PORTO\\the-movies-weekly-bc77a4292aef.json"
SERVICE_ACCOUNT_FILE = pathjsonnn

credentials = service_account.Credentials.from_service_account_file(
    SERVICE_ACCOUNT_FILE
)

pandas_gbq.context.credentials = credentials
pandas_gbq.context.project = project_id

# %%
table_indo = f"{dataset_id}.trending_movie_week_indo"

pandas_gbq.to_gbq(
    df_movie_id,
    destination_table=table_indo,
    project_id=project_id,
    if_exists="replace"
)

table_global = f"{dataset_id}.trending_movie_week_global"

pandas_gbq.to_gbq(
    df_movie_global,
    destination_table=table_global,
    project_id=project_id,
    if_exists="replace"
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 4165.15it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12446.01it/s]
